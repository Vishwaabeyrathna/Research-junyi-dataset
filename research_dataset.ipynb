# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install 'longling[ml]' EduData
# !edudata download junyi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
# Traceback (most recent call last):
#   File "/usr/local/bin/edudata", line 5, in <module>
#     from EduData.main import cli
#   File "/usr/local/lib/python3.13/dist-packages/EduData/main.py", line 9, in <module>
#     from longling.ML.toolkit.dataset import train_valid_test, kfold
# ModuleNotFoundError: No module named 'longling.ML'

# %%
from EduData import get_data
get_data("junyi", "./")
# Out:
# downloader, INFO http://base.ustc.edu.cn/data/JunyiAcademy_Math_Practicing_Log/junyi.rar is saved as junyi.rar
# ...
# downloader, INFO junyi.rar is unrar to junyi
# 'junyi'

# %%
import os
for root, dirs, files in os.walk("."):
    for f in files:
        if f.endswith(".csv"):
            print(os.path.join(root, f))
# Out:
# ./junyi/junyi_Exercise_table.csv
# ./junyi/relationship_annotation_training.csv
# ./junyi/relationship_annotation_testing.csv
# ./junyi/junyi_ProblemLog_original.csv
# ./sample_data/mnist_test.csv
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_train.csv
# ./sample_data/california_housing_test.csv

# %%
import pandas as pd

# %%
ex = pd.read_csv("./junyi/junyi_Exercise_table.csv", encoding="utf-8", low_memory=False)
print("EXERCISE TABLE:", ex.shape)
print(ex.columns.tolist())
print()
ex.head(10)
# Out:
# EXERCISE TABLE: (837, 11)
# ['name', 'live', 'prerequisites', 'h_position', 'v_position', 'creation_date', 'seconds_per_fast_problem', 'pretty_display_name', 'short_display_name', 'topic', 'area']
#                               name  live  \
# 0             parabola_intuition_1  True
# 1                 circles_and_arcs  True
# 2               inscribed_angles_3  True
# 3  solving_quadratics_by_factoring  True
# 4             graphing_parabolas_1  True
# 5            inverses_of_functions  True
# 6               one_step_equations  True
# 7            one_step_inequalities  True
# 8  number_properties_terminology_1  True
# 9                         angles_2  True
#
#                                prerequisites  h_position  v_position  \
# 0                 recognizing_conic_sections          47           2
# 1                                        NaN          40         -20
# 2                         inscribed_angles_2          44         -22
# ...

# %%
rel = pd.read_csv("./junyi/relationship_annotation_training.csv", encoding="utf-8", low_memory=False)
print("RELATIONSHIPS:", rel.shape)
print(rel.columns.tolist())
rel.head(10)
# Out:
# RELATIONSHIPS: (1131, 8)
# ['Exercise_A', 'Exercise_B', 'Similarity_avg', 'Similarity_raw', 'Difficulty_avg', 'Difficulty_raw', 'Prerequisite_avg', 'Prerequisite_raw']
#                           Exercise_A  \
# 0  radius_diameter_and_circumference
# 1  radius_diameter_and_circumference
# 2  radius_diameter_and_circumference
# 3               vertex_of_a_parabola
# 4               vertex_of_a_parabola
# 5               vertex_of_a_parabola
# 6               vertex_of_a_parabola
# 7               vertex_of_a_parabola
# 8                     triangle_types
# 9                     triangle_types
#
#                                      Exercise_B  Similarity_avg  \
# 0                    arithmetic_word_problems_1        1.857143
# 1                              parts_of_circles        6.785714
# 2           perimeter_of_squares_and_rectangles        3.571429
# 3  solving_quadratics_by_taking_the_square_root        5.923077
# ...

# %%
edges = ex[ex["prerequisites"].notna()][["name", "prerequisites"]]
print("total edges:", len(edges))

strong = rel[rel["Prerequisite_avg"] >= 6.0]
weak   = rel[rel["Prerequisite_avg"] <= 3.0]
print("strong prerequisite pairs:", len(strong))
print("weak/non pairs:", len(weak))
# Out:
# total edges: 742
# strong prerequisite pairs: 357
# weak/non pairs: 258
